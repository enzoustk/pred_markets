# %%
import pandas as pd

# %%
df = pd.read_csv('all_trades_0x2c335066_maker_taker_full.csv')

# %%
df_knicks = df[df['slug'] == 'nba-cle-nyk-2025-10-22-spread-home-2pt5']

# %%
df_knicks_home = df_knicks[df_knicks['outcome'] == 'Knicks']

# %%
df_knicks_home
# Out:
#                                      proxyWallet side  \
# 1979  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1980  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1982  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1983  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1984  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1985  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1990  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1992  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1993  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1994  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1995  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1996  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1997  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1998  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 1999  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# 2000  0x2c335066fe58fe9237c3d3dc7b275c2a034a0563  BUY
# ...
